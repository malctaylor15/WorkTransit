# %%
import os 
import sys
import logging
import re 
import datetime
import pickle
# logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append('/home/malcolm/WorkTransit/scripts/')

# %%
import WorkTransitLib.RawDirections as rd
import WorkTransitLib.parseRawResponse as parser

# %%
now = datetime.datetime.now()
print(now)
time_hour = now.time().hour 
weekday = now.weekday()
# Out:
# 2021-11-26 00:41:26.228719

# %% [raw]
# time_hour = 20
# weekday = 6

# %%
# Weekend Morning 
if (weekday >= 5) & (8 <= time_hour <= 12):
    time_based_param_set = ['home_beach_driving']
# Weekend Evening
elif (weekday >= 5) & (12 <= time_hour <= 20):
    time_based_param_set = ['beach_home_driving']
# WeekDay Morning
elif (weekday < 5) & (5 <= time_hour <= 10):
    time_based_param_set = ['home_work_driving', 'home_work_transit', 'home_bxbark_driving', 'bxbark_work_driving']
# WeekDay Evening
elif (weekday < 5) & (15 <= time_hour <= 22):
    time_based_param_set = ['work_home_driving', 'work_home_transit', 'work_bxbark_driving', 'bxbark_home_driving']
else: 
    time_based_param_set = ['home_beach_driving', 'beach_home_driving']
    print('Uhoh')

print("Params: ", time_based_param_set)
print('Weekday: ', weekday, "Time Hour: ", time_hour)
# Out:
# Uhoh
# Params:  ['home_beach_driving', 'beach_home_driving']
# Weekday:  4 Time Hour:  0

# %%
try:
    db_updater = rd.GetRawAPI()
    db_updater.execute(param_names = time_based_param_set)
    print(db_updater.updated_params_df)
    
    driving_parser = parser.RunParser('driving', 'parsed_driving')
    driving_parser.execute()
    
    transit_parser = parser.RunParser('transit', 'parsed_transit')
    transit_parser.execute()
    

    
    hp_error = None
except Exception as e:
    hp_error = str(e)
    print("Error: ", hp_error)
# Out:
# Let's get started
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/directions/json?departure_time=1637905466&destination=Orchard+Beach%2C+Bronx%2C+NY+10464&mode=driving&origin=120+Benchley+Pl%2C+Bronx+NY&key=AIzaSyDH-PfAbe6bwg3oHogUlJcPuPfkIrmOy7c HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/directions/json?departure_time=1637905466&destination=120+Benchley+Pl%2C+Bronx+NY&mode=driving&origin=Orchard+Beach%2C+Bronx%2C+NY+10464&key=AIzaSyDH-PfAbe6bwg3oHogUlJcPuPfkIrmOy7c HTTP/1.1" 200 None
# Added to /home/malcolm/WorkTransit/data/transit.db
#                            origin                     destination     mode  \
# 0       120 Benchley Pl, Bronx NY  Orchard Beach, Bronx, NY 10464  driving
# 1  Orchard Beach, Bronx, NY 10464       120 Benchley Pl, Bronx NY  driving
#
#                departure_time  \
# 0  2021-11-26 00:44:26.057967
# 1  2021-11-26 00:44:26.057967
#
#                                         Raw Response        Date   Time
# 0  [{'bounds': {'northeast': {'lat': 40.8745759, ...  2021-11-26  00:44
# 1  [{'bounds': {'northeast': {'lat': 40.874488100...  2021-11-26  00:44
# DEBUG:WorkTransitLib.parseRawResponse:Latest date for parsed_driving is 2021-11-26 00:07:09.981178
# DEBUG:WorkTransitLib.parseRawResponse:Starting parse raw
# /home/malcolm/main/lib/python3.6/site-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/malcolm/main/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-178dbd248f4d>", line 7, in <module>
#     driving_parser.execute()
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 180, in execute
#     self.create_con(db_path)
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 119, in create_con
#     logger.debug("Tables: ", tables)
# Message: 'Tables: '
# Arguments: (['Raw_Responses', 'parsed_driving', 'parsed_transit'],)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/malcolm/main/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-178dbd248f4d>", line 7, in <module>
#     driving_parser.execute()
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 185, in execute
#     self.raw_df = self.get_raw_responses_df2(self.latest_date_time)
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 149, in get_raw_responses_df2
#     logger.debug("Raw Response df has ", raw_df.shape[0], " rows")
# Message: 'Raw Response df has '
# Arguments: (12, ' rows')
# DEBUG:WorkTransitLib.parseRawResponse:Latest date for parsed_transit is 2021-11-25 19:48:21.754542
# DEBUG:WorkTransitLib.parseRawResponse:Starting parse raw
# /home/malcolm/main/lib/python3.6/site-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/malcolm/main/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-178dbd248f4d>", line 7, in <module>
#     driving_parser.execute()
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 188, in execute
#     self.update_table(self.full_df)
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 175, in update_table
#     logger.debug(self.parsed_tbl_name, " was updated with ", full_df.shape[0], " rows")
# Message: 'parsed_driving'
# Arguments: (' was updated with ', 12, ' rows')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/malcolm/main/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-178dbd248f4d>", line 10, in <module>
#     transit_parser.execute()
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 180, in execute
#     self.create_con(db_path)
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 119, in create_con
#     logger.debug("Tables: ", tables)
# Message: 'Tables: '
# Arguments: (['Raw_Responses', 'parsed_driving', 'parsed_transit'],)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/malcolm/main/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-178dbd248f4d>", line 10, in <module>
#     transit_parser.execute()
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 185, in execute
#     self.raw_df = self.get_raw_responses_df2(self.latest_date_time)
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 149, in get_raw_responses_df2
#     logger.debug("Raw Response df has ", raw_df.shape[0], " rows")
# Message: 'Raw Response df has '
# Arguments: (1, ' rows')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/malcolm/main/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/malcolm/main/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/malcolm/main/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-178dbd248f4d>", line 10, in <module>
#     transit_parser.execute()
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 188, in execute
#     self.update_table(self.full_df)
#   File "/home/malcolm/WorkTransit/scripts/WorkTransitLib/parseRawResponse.py", line 175, in update_table
#     logger.debug(self.parsed_tbl_name, " was updated with ", full_df.shape[0], " rows")
# Message: 'parsed_transit'
# Arguments: (' was updated with ', 1, ' rows')

# %%
sys.path.append('/home/malcolm/EmailSender/')
from EmailSender import EmailSender as ES

# %%
today_str = str(datetime.datetime.now().date())
if isinstance(hp_error, str):
    error_email = {}
    error_email['Subject'] = "Error in Google Directions "+today_str
    error_email['Body'] = """
        There was an error in Google Directions data pull. 

        Stack Trace: 

        """ + hp_error

    email_sender = ES(**error_email)
    email_sender.execute()

# %%
today_str = str(datetime.datetime.now().date())

if isinstance(hp_error, str):
    subject = "Error in Google Directions "+today_str
    message["Subject"] = subject

    
    body = """
        There was an error in Google Directions data pull. 

        Coming from Digital Ocean Droplet 

        Stack Trace: 

        """ + hp_error
    
    text = MIMEText(body, "plain")
    message.attach(text)
             
    print("Starting email send")
    with smtplib.SMTP_SSL("smtp.gmail.com", port, context=context) as server:
        server.login(gmail_login, pw)
        message_str = message.as_string()
        server.sendmail(gmail_login, reciever_email, message_str)
