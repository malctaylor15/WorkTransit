# %%
import pandas as pd 
import sqlite3 
import numpy as np 
import datetime
import sys 
import os 
from ast import literal_eval
# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append('/home/malcolm/WorkTransit/scripts/WorkTransitLib/')

# %%
import RawDirections as rd

# %%
con = sqlite3.connect('/home/malcolm/WorkTransit/data/transit.db')
cursor = con.cursor()
cursor.execute('SELECT name FROM sqlite_master WHERE type=\'table\' ORDER BY name')
tables = cursor.fetchall()
tables
# Out:
# [('Raw_Responses',)]

# %%
df = pd.read_sql('select * from raw_responses', con)
df
# Out:
#                              origin                     destination     mode  \
# 0         120 Benchley Pl, Bronx NY           809 Washington Street  driving
# 1         120 Benchley Pl, Bronx NY           809 Washington Street  transit
# 2         120 Benchley Pl, Bronx NY           809 Washington Street  driving
# 3         120 Benchley Pl, Bronx NY           809 Washington Street  transit
# 4         120 Benchley Pl, Bronx NY           809 Washington Street  driving
# ..                              ...                             ...      ...
# 143  Orchard Beach, Bronx, NY 10464       120 Benchley Pl, Bronx NY  driving
# 144       120 Benchley Pl, Bronx NY  Orchard Beach, Bronx, NY 10464  driving
# 145  Orchard Beach, Bronx, NY 10464       120 Benchley Pl, Bronx NY  driving
# 146       120 Benchley Pl, Bronx NY  Orchard Beach, Bronx, NY 10464  driving
# 147  Orchard Beach, Bronx, NY 10464       120 Benchley Pl, Bronx NY  driving
#
#                  departure_time  \
# 0    2021-09-03 09:29:53.537614
# 1    2021-09-03 09:29:53.537614
# 2    2021-09-03 11:09:25.191728
# 3    2021-09-03 11:09:25.191728
# 4    2021-09-03 11:11:19.014920
# ..                          ...
# 143  2021-09-06 19:00:09.699638
# 144  2021-09-06 19:17:29.822629
# 145  2021-09-06 19:17:29.822629
# 146  2021-09-06 19:30:13.377936
# 147  2021-09-06 19:30:13.377936
#
#                                           Raw Response        Date   Time
# 0    [{'bounds': {'northeast': {'lat': 40.8745759, ...  2021-09-03  09:29
# 1    [{'bounds': {'northeast': {'lat': 40.874488100...  2021-09-03  09:29
# 2    [{'bounds': {'northeast': {'lat': 40.9347924, ...  2021-09-03  11:09
# 3    [{'bounds': {'northeast': {'lat': 40.874488100...  2021-09-03  11:09
# 4    [{'bounds': {'northeast': {'lat': 40.9347924, ...  2021-09-03  11:11
# ..                                                 ...         ...    ...
# 143  [{'bounds': {'northeast': {'lat': 40.874488100...  2021-09-06  19:00
# 144  [{'bounds': {'northeast': {'lat': 40.8745759, ...  2021-09-06  19:17
# 145  [{'bounds': {'northeast': {'lat': 40.874488100...  2021-09-06  19:17
# 146  [{'bounds': {'northeast': {'lat': 40.8745759, ...  2021-09-06  19:30
# 147  [{'bounds': {'northeast': {'lat': 40.874488100...  2021-09-06  19:30
#
# [148 rows x 7 columns]

# %%
def parse_time(x):
    return(str(datetime.datetime.utcfromtimestamp(x)))
def parse_duration(x):
    return(np.round(x/3600.0, 2))
def parse_distance(x):
    return(np.round(x/1609.34, 2))

# %%
def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %% [markdown]
# ## Driving

# %%
temp = df[(df['destination'] == rd.work) &
   (df['mode'] == 'driving')].iloc[1]
driving_resp = literal_eval(temp['Raw Response'])[0]
driving_resp
# Out:
# {'bounds': {'northeast': {'lat': 40.9347924, 'lng': -73.808418},
#   'southwest': {'lat': 40.7391335, 'lng': -74.00886710000002}},
#  'copyrights': 'Map data ©2021 Google',
#  'legs': [{'distance': {'text': '24.1 mi', 'value': 38833},
#    'duration': {'text': '46 mins', 'value': 2752},
#    'duration_in_traffic': {'text': '50 mins', 'value': 2986},
#    'end_address': '809 Washington St, New York, NY 10014, USA',
#    'end_location': {'lat': 40.7391335, 'lng': -74.0080765},
#    'start_address': '120 Benchley Pl, Bronx, NY 10475, USA',
#    'start_location': {'lat': 40.87448810000001, 'lng': -73.82567019999999},
#    'steps': [{'distance': {'text': '210 ft', 'value': 64},
#      'duration': {'text': '1 min', 'value': 23},
#      'end_location': {'lat': 40.87422850000001, 'lng': -73.8257921},
#      'html_instructions': 'Head <b>northwest</b> toward <b>Benchley Pl</b>',
#      'polyline': {'points': 'qhnxFlaraMA?A@A?A@A@A@?@A??@A@?@?@?@?@A??@?@?@?@@??@?@?@?@@??@?@@??@@??@@@@??@@?@@@?@?@?@?@?j@['},
#      'start_location': {'lat': 40.87448810000001, 'lng': -73.82567019999999},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '187 ft', 'value': 57},
#      'duration': {'text': '1 min', 'value': 53},
#      'end_location': {'lat': 40.873769, 'lng': -73.82609219999999},
#      'html_instructions': 'Turn <b>right</b> onto <b>Benchley Pl</b>',
#      'maneuver': 'turn-right',
#      'polyline': {'points': '}fnxFdbraMLJLDJFNJXNHD'},
#      'start_location': {'lat': 40.87422850000001, 'lng': -73.8257921},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '463 ft', 'value': 141},
#      'duration': {'text': '1 min', 'value': 48},
#      'end_location': {'lat': 40.87368499999999, 'lng': -73.8244583},
#      'html_instructions': 'Turn <b>left</b> onto <b>Bellamy Loop</b>',
#      'maneuver': 'turn-left',
#      'polyline': {'points': 'adnxF`draMLa@DUDUBU@YAU?AE{AEsA'},
#      'start_location': {'lat': 40.873769, 'lng': -73.82609219999999},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.5 mi', 'value': 785},
#      'duration': {'text': '2 mins', 'value': 99},
#      'end_location': {'lat': 40.8800041, 'lng': -73.82326309999999},
#      'html_instructions': 'Turn <b>left</b> onto <b>Co Op City Blvd</b>',
#      'maneuver': 'turn-left',
#      'polyline': {'points': 'ocnxFzyqaMA]YBgAHWBG?SBU@I@I?U@Y?WAY?YCYAUCOCGAUG_@G[IKC_@Kq@WQIKEUMKEOGUOYQSOSOs@k@a@]]Y_@W[Sa@QWISG[I[EWCUCS?S?M@MBKBKFE@CBIFKJGHKPEFADGNGTCNAR'},
#      'start_location': {'lat': 40.87368499999999, 'lng': -73.8244583},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.2 mi', 'value': 259},
#      'duration': {'text': '1 min', 'value': 45},
#      'end_location': {'lat': 40.8822367, 'lng': -73.82346840000001},
#      'html_instructions': 'Turn <b>right</b> onto <b>Peartree Ave</b>',
#      'maneuver': 'turn-right',
#      'polyline': {'points': '_koxFjrqaM_Da@oAQ]CE?E?SDw@\\yA|@'},
#      'start_location': {'lat': 40.8800041, 'lng': -73.82326309999999},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.3 mi', 'value': 560},
#      'duration': {'text': '2 mins', 'value': 121},
#      'end_location': {'lat': 40.8859402, 'lng': -73.82789509999999},
#      'html_instructions': 'Merge onto <b>Conner St</b><div style="font-size:0.9em">Pass by Taco Bell (on the left)</div>',
#      'maneuver': 'merge',
#      'polyline': {'points': '_yoxFtsqaM_@VQLKJKJIHOPINu@pAOXYd@O^ELMXABUb@Y`@YXABOPGDCDOP[^w@|@KLKLMPIVKJ]d@CBSVKNGFYZIHGF]ZQNOLYREBQN'},
#      'start_location': {'lat': 40.8822367, 'lng': -73.82346840000001},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.8 mi', 'value': 1263},
#      'duration': {'text': '3 mins', 'value': 170},
#      'end_location': {'lat': 40.8921333, 'lng': -73.8153633},
#      'html_instructions': 'Turn <b>right</b> onto <b>US-1 N</b>/<wbr/><b>Boston Rd</b><div style="font-size:0.9em">Continue to follow US-1 N</div><div style="font-size:0.9em">Pass by Wendy\'s (on the right in 0.5&nbsp;mi)</div>',
#      'maneuver': 'turn-right',
#      'polyline': {'points': 'cppxFjoraMOo@GSSq@AEYaACIEO_AcD_@uAMa@So@GOIQMYO_@KSCECCMUKSUc@[o@m@iAMYOY{A{CsBeEO[o@uAO_@Qg@g@mAGOc@cAWk@GKCGOYYm@c@gAc@aAMUGSSm@GQGQK[Sm@CMWy@YcA[}@Ww@Si@M_@Qg@Qg@'},
#      'start_location': {'lat': 40.8859402, 'lng': -73.82789509999999},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.2 mi', 'value': 289},
#      'duration': {'text': '1 min', 'value': 25},
#      'end_location': {'lat': 40.89446909999999, 'lng': -73.8167823},
#      'html_instructions': 'Turn <b>left</b> onto the ramp to <b>Hutchinson Pkwy North</b>',
#      'maneuver': 'ramp-left',
#      'polyline': {'points': 'yvqxF~`paMSJURUTML?@IHIJIJIHEFKFKHOHSJMFSHGBs@Xe@Nq@Pu@P]JQH'},
#      'start_location': {'lat': 40.8921333, 'lng': -73.8153633},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '1.9 mi', 'value': 3038},
#      'duration': {'text': '3 mins', 'value': 166},
#      'end_location': {'lat': 40.9208807, 'lng': -73.8100173},
#      'html_instructions': 'Merge onto <b>Hutchinson River Pkwy N</b>',
#      'maneuver': 'merge',
#      'polyline': {'points': 'merxFzipaMUBUBs@DW?Q?_@AeAKe@I]G[G]I{@S{@WOEEAEAa@Mk@S{@Yw@WKCYIA?c@Ki@Kk@ISCUCKA]Ci@CEA_AC_BAUAU@a@?o@CQCOASC_@GC?SEMCSEKCKCMCOEq@Us@[UKe@Ue@UaAe@EAIE[M]Oq@WaA]YKOEmA]a@Ic@MUGq@MaASMCWCcBQSA}@EOAg@As@@s@By@Ju@Jk@N{@VgAb@WJE@WHWFM@_@Dk@@_@?a@A[G]Ea@KeBe@c@Ma@M]Ke@OOG[KWKYKsBu@a@OMGEA]KqAa@y@S[Ii@Mk@OYGg@KkAWYEMCc@Iw@Me@ISCCAaFu@[IeAWSGkA]sCgAGAIEME_Bm@[MOGe@QECSIUIcAg@'},
#      'start_location': {'lat': 40.89446909999999, 'lng': -73.8167823},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text':
#  'overview_polyline': {'points': 'qhnxFlaraMQVNZF?@?j@[LJXLh@ZHDLa@Jk@BgAKoDA]YB_BL[B_ADmDQ}A]oBs@}DiC{BcBiBm@}AM{@HeAdAUz@AR_Da@mBUwAb@wCnBo@v@oBpDk@nAeApAuChDw@lAaAjAcCrBqC{JiAwDs@_BaCqEmFuKaByDaDiHmCaH_DyJc@oAi@^m@n@_BpAiGnBqBVoCMkGwAoFcBmCe@iBMuHOiCa@{Ac@uCsAyGmC{HiBmE]_D@oBVgBf@}Bz@qBP{BO}H}ByFsBkKiCcLgBaEgAsDuAeHuCyDiCy@o@Wg@?m@Zm@h@AZXVt@LfAGfBUhEm@hLUtC_ApEgA|EGr@AhAN`Bj@pEGfEi@rEKhB}AnMi@vCiBdGyC|HiCdI_A`F[nDEhCIzJMbBiBzLqBdMwA~FeCxJaAbF{@`GcApK}AhQc@dGqBdQkD~SyClQyBtLwAjDe@r@wChEsA|Ce@jCSjCNhE`@nBjErLxCxHnBlHbAjGd@|FAxCSrD{@`Em@|Aw@pCBjAZfA|@~@n@PzGl@`ADbA[dByAbAe@pAKhB\\hAh@bEpC`ChA`Bh@dBVdJ\\zB`@bEvA|JzDfGvAbQlC~UpDnGtAdFjBxCnArHhC~O~DtE|AtGfCzC~A~BpCzAzDr@bGHnDKvDWlD{@xFeBnIoAjIc@pEQbF@`G\\bFz@xEp@nB~@`BlBnBzAnAtBhAlA`@nDf@zJ`@|ENbT@xAFrATnAh@t@n@l@v@pBlEzAhDtBnCvCnB~DjDpBjC~BlDpAdAlC`ApAj@rBrAzB~BzF~GhF`HfDjGbIjNh@|@|@dBbBfFnAnCdBvC`CbD|BbC`BxAhC`BfH`DbIfDnDvAzInEbDfBjEbBtD|AbHhEzCdB~DfBdFlDlH~FxEfDzJlGbHxD~E~CjBbBdC~CdEhFtC`BvAb@xAP`F@lLWdIIdHl@hCh@nC`AxDdBtClBnEtDzCtCjCfBfD|@xPfDlJnB`Bd@hDvAfFdDbGlFrPfOnGtEjKpHxJzHjExDbHlHfFzEbF|CzHhEvCtBnEvCdQpJzR|MxMbJxMxHpG|BvGlB|Bv@nDpBpEvExCpD`@d@rFnFnI~FpIjEnGzB`IvB~CpAnWnP`DlCzBtBvJzGrNlJrSzM`GrDdCd@fDVdCp@~RnMfMlIvBlBpEjH~@jAbGdEhMjIdVzO`CrApPpEdBb@`AHpBKjEgBvBOrO`BnKjA~@Hr@HrAN^_@Be@l@_A`@gBZ{@^iAPJvDdC~@j@xDPp@D'},
#  'summary': 'NY-9A S',
#  'warnings': [],
#  'waypoint_order': []}

# %%
driving_resp.keys()
# Out:
# dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])

# %%
[print(k, type(v), str(v)[:150]) for k, v in driving_resp['legs'][0].items()]
# Out:
# distance <class 'dict'> {'text': '24.1 mi', 'value': 38833}
# duration <class 'dict'> {'text': '46 mins', 'value': 2752}
# duration_in_traffic <class 'dict'> {'text': '50 mins', 'value': 2986}
# end_address <class 'str'> 809 Washington St, New York, NY 10014, USA
# end_location <class 'dict'> {'lat': 40.7391335, 'lng': -74.0080765}
# start_address <class 'str'> 120 Benchley Pl, Bronx, NY 10475, USA
# start_location <class 'dict'> {'lat': 40.87448810000001, 'lng': -73.82567019999999}
# steps <class 'list'> [{'distance': {'text': '210 ft', 'value': 64}, 'duration': {'text': '1 min', 'value': 23}, 'end_location': {'lat': 40.87422850000001, 'lng': -73.82579
# traffic_speed_entry <class 'list'> []
# via_waypoint <class 'list'> []
# [None, None, None, None, None, None, None, None, None, None]

# %%
def summarize_leg_step(step):
    out = {}
    out['distance_mi'] = parse_distance(step['distance']['value'])
    out['duration_hr'] = parse_duration(step['duration']['value'])
    out['instructions'] = remove_html_tags(step['html_instructions'])
    
    out['distance_text'] = step['distance']['text']
    out['duration_text'] = step['duration']['text']
    
    out_series = pd.Series(out)
    return(out_series)

# %%
def consolidate_steps(driving_steps_dict):
    concise_steps = pd.DataFrame([summarize_leg_step(x) for x in driving_steps_dict])
    concise_steps = concise_steps.reset_index().rename({'index':'Step #'}, axis=1)
    concise_steps = concise_steps.sort_values('duration_hr', ascending=False)
    return(concise_steps)

# %%
legs = driving_resp['legs'][0]

# %%
concise_steps = consolidate_steps(legs['steps'])
concise_steps.iloc[:3]
# Out:
#     Step #  distance_mi  duration_hr  \
# 15      15         8.15         0.26
# 14      14         4.66         0.10
# 9        9         2.00         0.05
#
#                                          instructions distance_text  \
# 15                      Keep right to stay on NY-9A S        8.2 mi
# 14   Continue onto NY-9A S/Henry Hudson PkwyToll road        4.7 mi
# 9   Take exit 6B to merge onto Cross County Pkwy t...        2.0 mi
#
#    duration_text
# 15       16 mins
# 14        6 mins
# 9         3 mins

# %%
def parse_driving_details(driving_resp):
    
    legs = driving_resp['legs'][0]
    concise_steps = consolidate_steps(legs['steps'])

    driving_details = {}
    driving_details['summary'] = driving_resp['summary']
    driving_details['duration_hr'] = parse_duration(legs['duration']['value'])
    driving_details['duration_text'] = legs['duration']['text']

    driving_details['duration_in_traffic_hr'] = parse_duration(legs['duration_in_traffic']['value'])
    driving_details['duration_in_traffic_text'] = legs['duration_in_traffic']['text']
    
    driving_details['extra time in traffic_min'] = np.round((driving_details['duration_in_traffic_hr'] - driving_details['duration_hr'])*60.0, 2)
    
    driving_details['distance_mi'] = parse_distance(legs['distance']['value'])


    driving_details['1st Longest Step (time)'] = str(concise_steps.iloc[0].to_dict())
    driving_details['2nd Longest Step (time)'] = str(concise_steps.iloc[1].to_dict())
    driving_details['3rd Longest Step (time)'] = str(concise_steps.iloc[2].to_dict())

    return(pd.Series(driving_details))

# %%
driving_details1 = parse_driving_details(driving_resp)
driving_details1
# Out:
# summary                                                               NY-9A S
# duration_hr                                                              0.76
# duration_text                                                         46 mins
# duration_in_traffic_hr                                                   0.83
# duration_in_traffic_text                                              50 mins
# time in traffic_min                                                       4.2
# distance_mi                                                             24.13
# 1st Longest Step (time)     {'Step #': 15, 'distance_mi': 8.15, 'duration_...
# 2nd Longest Step (time)     {'Step #': 14, 'distance_mi': 4.66, 'duration_...
# 3rd Longest Step (time)     {'Step #': 9, 'distance_mi': 2.0, 'duration_hr...
# dtype: object

# %% [markdown]
# ## Sample Transit Parse

# %%
temp = df[(df['destination'] == rd.work) &
   (df['mode'] == 'transit')].iloc[1]
transit_resp = literal_eval(temp['Raw Response'])[0]
transit_resp
# Out:
# {'bounds': {'northeast': {'lat': 40.87448810000001, 'lng': -73.82567019999999},
#   'southwest': {'lat': 40.7378273, 'lng': -74.0080004}},
#  'copyrights': 'Map data ©2021 Google',
#  'legs': [{'arrival_time': {'text': '12:49pm',
#     'time_zone': 'America/New_York',
#     'value': 1630687792},
#    'departure_time': {'text': '11:22am',
#     'time_zone': 'America/New_York',
#     'value': 1630682555},
#    'distance': {'text': '16.0 mi', 'value': 25753},
#    'duration': {'text': '1 hour 27 mins', 'value': 5237},
#    'end_address': '809 Washington St, New York, NY 10014, USA',
#    'end_location': {'lat': 40.7389303, 'lng': -74.0079928},
#    'start_address': '120 Benchley Pl, Bronx, NY 10475, USA',
#    'start_location': {'lat': 40.87448810000001, 'lng': -73.82567019999999},
#    'steps': [{'distance': {'text': '0.3 mi', 'value': 537},
#      'duration': {'text': '7 mins', 'value': 390},
#      'end_location': {'lat': 40.8711287, 'lng': -73.82836329999999},
#      'html_instructions': 'Walk to Asch Loop/Adler Pl',
#      'polyline': {'points': 'qhnxFlaraM@?@?@?@?B@LFTr@FDJDVNB@ZNGVXN`Ad@Mr@Ox@b@PF?FC@D?@@??@?@@??@@??@@?@@@@@??@@?@?@?@@@?@?@A@?@?@??A@?@A@??A@?@AHC|@^D@j@VXJLHNHFFRHVj@BD?@B@DDDDHFJBTNFB^LD?NBV@L@@I'},
#      'start_location': {'lat': 40.87448810000001, 'lng': -73.82567019999999},
#      'steps': [{'distance': {'text': '266 ft', 'value': 81},
#        'duration': {'text': '1 min', 'value': 61},
#        'end_location': {'lat': 40.8738716, 'lng': -73.8262099},
#        'html_instructions': 'Head <b>south</b> on <b>Benchley Pl</b> toward <b>Benchley Pl</b>',
#        'polyline': {'points': 'qhnxFlaraM@?@?@?@?B@LFTr@FDJDVNB@ZN'},
#        'start_location': {'lat': 40.87448810000001, 'lng': -73.82567019999999},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '82 ft', 'value': 25},
#        'duration': {'text': '1 min', 'value': 18},
#        'end_location': {'lat': 40.8739115, 'lng': -73.82633109999999},
#        'html_instructions': 'Turn <b>right</b>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'udnxFxdraMGV'},
#        'start_location': {'lat': 40.8738716, 'lng': -73.8262099},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '184 ft', 'value': 56},
#        'duration': {'text': '1 min', 'value': 41},
#        'end_location': {'lat': 40.8734494, 'lng': -73.8265959},
#        'html_instructions': 'Turn <b>left</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': '}dnxFperaMXN`Ad@'},
#        'start_location': {'lat': 40.8739115, 'lng': -73.82633109999999},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '164 ft', 'value': 50},
#        'duration': {'text': '1 min', 'value': 36},
#        'end_location': {'lat': 40.87360380000001, 'lng': -73.82715449999999},
#        'html_instructions': 'Turn <b>right</b>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'abnxFfgraMMr@Ox@'},
#        'start_location': {'lat': 40.8734494, 'lng': -73.8265959},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '121 ft', 'value': 37},
#        'duration': {'text': '1 min', 'value': 26},
#        'end_location': {'lat': 40.8733432, 'lng': -73.827225},
#        'html_instructions': 'Turn <b>left</b> toward <b>Adler Pl</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': '_cnxFtjraMb@PF?FC'},
#        'start_location': {'lat': 40.87360380000001, 'lng': -73.82715449999999},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '56 ft', 'value': 17},
#        'duration': {'text': '1 min', 'value': 12},
#        'end_location': {'lat': 40.8730628, 'lng': -73.8272726},
#        'html_instructions': 'Slight <b>right</b> toward <b>Adler Pl</b>',
#        'maneuver': 'turn-slight-right',
#        'polyline': {'points': 'kanxFbkraM@D?@@??@?@@??@@??@@?@@@@@??@@?@?@?@@@?@?@A@?@?@??A@?@A@??A@?@AHC'},
#        'start_location': {'lat': 40.8733432, 'lng': -73.827225},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '0.2 mi', 'value': 256},
#        'duration': {'text': '3 mins', 'value': 185},
#        'end_location': {'lat': 40.8711411, 'lng': -73.82840680000001},
#        'html_instructions': 'Turn <b>right</b> onto <b>Adler Pl</b>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 's_nxFlkraM|@^D@j@VXJLHNHFFRHVj@BD?@B@DDDDHFJBTNFB^LD?NBV@L@'},
#        'start_location': {'lat': 40.8730628, 'lng': -73.8272726},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '49 ft', 'value': 15},
#        'duration': {'text': '1 min', 'value': 11},
#        'end_location': {'lat': 40.8711287, 'lng': -73.82836329999999},
#        'html_instructions': 'Turn <b>right</b> onto <b>Asch Loop</b><div style="font-size:0.9em">Destination will be on the right</div>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'ssmxFprraM@I'},
#        'start_location': {'lat': 40.8711411, 'lng': -73.82840680000001},
#        'travel_mode': 'WALKING'}],
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '1.2 mi', 'value': 1862},
#      'duration': {'text': '9 mins', 'value': 552},
#      'end_location': {'lat': 40.8699, 'lng': -73.84509299999999},
#      'html_instructions': 'Bus towards Fordham Center 192 St Via Gunhill',
#      'polyline': {'points': 'gsmxF|rraMB??JAd@?PCr@C^AL?@AFEZCVAHIVS~@Op@Kf@pAp@PFJDPFB@NBPBTBZ@VAh@Ot@UJCFETIf@Qb@QXbBHf@XdBHXFZZvADR?DLd@?DNh@Nh@FN@DFJ?@DHBHDFFJDRDPFVDVNj@d@vBZrALj@Jf@HXNr@Lj@Lj@XlAZtAVhAZvAH\\Jb@BJJ`@a@|@MVEJy@nBcBzD]|@]t@Qd@ABO\\Uj@MX[v@O\\Qb@[r@_@`A_@z@IPEH}@zBKRIRo@xAWn@CE'},
#      'start_location': {'lat': 40.871082, 'lng': -73.828468},
#      'transit_details': {'arrival_stop': {'location': {'lat': 40.8699,
#         'lng': -73.84509299999999},
#        'name': 'E Gun Hill Rd/Knapp St'},
#       'arrival_time': {'text': '11:38am',
#        'time_zone': 'America/New_York',
#        'value': 1630683517},
#       'departure_stop': {'location': {'lat': 40.871082, 'lng': -73.828468},
#        'name': 'Asch Loop/Adler Pl'},
#       'departure_time': {'text': '11:29am',
#        'time_zone': 'America/New_York',
#        'value': 1630682965},
#       'headsign': 'Fordham Center 192 St Via Gunhill',
#       'line': {'agencies': [{'name': 'MTA', 'url': 'http://www.mta.info/'}],
#        'color': '#1d59b3',
#        'name': 'Co-op City Section 5 - Fordham Center',
#        'short_name': 'Bx28',
#        'text_color': '#ffffff',
#        'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#         'name': 'Bus',
#         'type': 'BUS'}},
#       'num_stops': 8},
#      'travel_mode': 'TRANSIT'},
#     {'distance': {'text': '0.1 mi', 'value': 177},
#      'duration': {'text': '3 mins', 'value': 164},
#      'end_location': {'lat': 40.869526, 'lng': -73.84638199999999},
#      'html_instructions': 'Walk to Gun Hill Rd',
#      'polyline': {'points': 'klmxFjzuaMVk@P|@IRIVYl@?@ADGLCDDDdB`C'},
#      'start_location': {'lat': 40.8699771, 'lng': -73.8450237},
#      'steps': [{'distance': {'text': '75 ft', 'value': 23},
#        'duration': {'text': '1 min', 'value': 16},
#        'end_location': {'lat': 40.8697689, 'lng': -73.8451095},
#        'html_instructions': 'Head <b>southeast</b> on <b>E Gun Hill Rd</b> toward <b>Knapp St</b>',
#        'polyline': {'points': 'klmxFjzuaMVk@P|@'},
#        'start_location': {'lat': 40.8699771, 'lng': -73.8450237},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '246 ft', 'value': 75},
#        'duration': {'text': '1 min', 'value': 68},
#        'end_location': {'lat': 40.870069, 'lng': -73.8457008},
#        'html_instructions': 'Cross the road<div style="font-size:0.9em">Destination will be on the left</div>',
#        'polyline': {'points': 'akmxF|zuaMIRIVYl@?@ADGLCD'},
#        'start_location': {'lat': 40.8697689, 'lng': -73.8451095},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '259 ft', 'value': 79},
#        'duration': {'text': '1 min', 'value': 80},
#        'end_location': {'lat': 40.869526, 'lng': -73.84638199999999},
#        'html_instructions': 'Take entrance <span class="location">East Gun Hill Rd & Dewitt Pl NW Corner</span>',
#        'polyline': {'points': 'wlmxFx~uaMdB`C'},
#        'start_location': {'lat': 40.870041, 'lng': -73.845726},
#        'travel_mode': 'WALKING'}],
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '6.3 mi', 'value': 10066},
#      'duration': {'text': '26 mins', 'value': 1530},
#      'end_location': {'lat': 40.8185709, 'lng': -73.9273257},
#      'html_instructions': 'Subway towards Flatbush Av-Brooklyn College',
#      'polyline': {'points': 'qimxFzbvaMz`Abw@fDjCNLNLNLLLLLNLJJNLLLJLLNHLLJJLJLdPfTle@pn@f@n@TXVXPRVRPPRL~@j@x@h@~@l@XPXNTNTLvAd@xCbAp@Vj@Vd@Zd@`@dAfA|@nAlGrI@?`BzBNRLVFRFTHd@t@zHH~@Bh@A`@?^C^GZIb@IXSp@Od@Oh@GNCPAT?VFZDRJRRTzAxA`@`@V\\LRLZRh@ZdAVz@Nr@NdADh@Bj@BpABtADr@Dx@L|@Nv@Pt@Nh@Tn@Xl@rFzKp@fAPTNNLLd@Zf@Xh@Vz_@tRh@Xt@Zh@Pv@P^FTBVB\\@`ZFxA?P@N@NFNFPLRPJPHPj@pA\\z@xJ|UfOl^|AvDx@rBrAzDnArDb@pAn@rAxEtJ|@pBVz@Hj@Fh@Dv@@rA?t@?v@ChAEnAIlCOdDMbCCn@Al@@l@Df@Jj@Rv@HRHVPp@Nt@Fh@@p@AdAEh@Ib@aAvE?@kM~v@]xBA?'},
#      'start_location': {'lat': 40.869526, 'lng': -73.84638199999999},
#      'transit_details': {'arrival_stop': {'location': {'lat': 40.8185709,
#         'lng': -73.9273257},
#        'name': '149 St - Grand Concourse'},
#       'arrival_time': {'text': '12:15pm',
#        'time_zone': 'America/New_York',
#        'value': 1630685700},
#       'departure_stop': {'location': {'lat': 40.869526,
#         'lng': -73.84638199999999},
#        'name': 'Gun Hill Rd'},
#       'departure_time': {'text': '11:49am',
#        'time_zone': 'America/New_York',
#        'value': 1630684170},
#       'headsign': 'Flatbush Av-Brooklyn College',
#       'line': {'agencies': [{'name': 'MTA New York City Transit',
#          'phone': '1 (718) 330-1234',
#          'url': 'http://www.mta.info/'}],
#        'color': '#00933c',
#        'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/us-ny-mta/5.png',
#        'name': '5 Line',
#        'short_name': '5',
#        'text_color': '#ffffff',
#        'url': 'http://web.mta.info/nyct/service/pdf/t5cur.pdf',
#        'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#         'name': 'Subway',
#         'type': 'SUBWAY'}},
#       'num_stops': 5},
#      'travel_mode': 'TRANSIT'},
#     {'distance': {'text': '7.7 mi', 'value': 12373},
#      'duration': {'text': '24 mins', 'value': 1410},
#      'end_location': {'lat': 40.737827, 'lng': -74.000198},
#      'html_instructions': 'Subway towards Flatbush Av-Brooklyn College',
#      'polyline': {'points': 'akcxFx|ebMUxA}@dFEb@G`@Gb@E`@E`@E`@Eb@C^Cb@C`@C^Ab@A`@A`@A^FnV?f@@d@Bd@Db@Db@Hb@H`@J^N^L^P^R\\RZVZVXzXzQng@p\\hb@vXzQvLn@b@b@`@R\\P\\Tn@Tz@Lz@LfArBdRzB|VDj@@d@Cf@Gh@Mf@Ql@Qj@_Kj[Kd@Id@Gb@Cb@Ab@@`@D^D^J^LZN\\RZVZXXZXb[pSPH~]rU~@v@nEnD`ClBxQdM|BxA^Tb@Rb@P`@Nn@Rl@NfFlAvHvAxBZhALn@FbAHhADxSVpC?jYUtAAPAVCVIh@OfA]TGRCVCV?VA\\@fAJfE\\dAL`AN|@PtA`@fA\\~@^z@`@tAn@`B~@vC`BhCvAj@\\l@X|@^r@T|@V|@RxCt@r@Ph@P\\JXLVLVNz@j@xKhHv]fUtRjMrRjM~QxL`SpM'},
#      'start_location': {'lat': 40.8185709, 'lng': -73.9273257},
#      'transit_details': {'arrival_stop': {'location': {'lat': 40.737827,
#         'lng': -74.000198},
#        'name': '14 St'},
#       'arrival_time': {'text': '12:40pm',
#        'time_zone': 'America/New_York',
#        'value': 1630687230},
#       'departure_stop': {'location': {'lat': 40.8185709, 'lng': -73.9273257},
#        'name': '149 St - Grand Concourse'},
#       'departure_time': {'text': '12:17pm',
#        'time_zone': 'America/New_York',
#        'value': 1630685820},
#       'headsign': 'Flatbush Av-Brooklyn College',
#       'line': {'agencies': [{'name': 'MTA New York City Transit',
#          'phone': '1 (718) 330-1234',
#          'url': 'http://www.mta.info/'}],
#        'color': '#ee352e',
#        'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/us-ny-mta/2.png',
#        'name': '2 Line',
#        'short_name': '2',
#        'text_color': '#ffffff',
#        'url': 'http://web.mta.info/nyct/service/pdf/t2cur.pdf',
#        'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#         'name': 'Subway',
#         'type': 'SUBWAY'}},
#       'num_stops': 9},
#      'travel_mode': 'TRANSIT'},
#     {'distance': {'text': '0.5 mi', 'value': 738},
#      'duration': {'text': '9 mins', 'value': 561},
#      'end_location': {'lat': 40.7389303, 'lng': -74.0079928},
#      'html_instructions': 'Walk to 809 Washington St, New York, NY 10014, USA',
#      'polyline': {'points': 'mrswFfdtbMe@Zk@hBEJGR]fAQh@Qf@Qh@IXCTCNCl@@hA?t@[h@h@j@?\\K??\\?~G?p@?`A@rAAd@?~GE?OA'},
#      'start_location': {'lat': 40.737827, 'lng': -74.000198},
#      'steps': [{'distance': {'text': '79 ft', 'value': 24},
#        'duration': {'text': '1 min', 'value': 25},
#        'end_location': {'lat': 40.7380196, 'lng': -74.00033719999999},
#        'html_instructions': 'Take exit <span class="location">7th Ave & 13th St at NW corner</span>',
#        'polyline': {'points': 'mrswFfdtbMe@Z'},
#        'start_location': {'lat': 40.737827, 'lng': -74.000198},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '0.1 mi', 'value': 196},
#        'duration': {'text': '2 mins', 'value': 137},
#        'end_location': {'lat': 40.7388386, 'lng': -74.0025615},
#        'html_instructions': 'Head <b>northwest</b> on <b>W 13th St</b> toward <b>Greenwich Ave</b>',
#        'polyline': {'points': 'ssswFbetbMk@hBEJGR]fAQh@Qf@Qh@IXCTCNCl@'},
#        'start_location': {'lat': 40.7380206, 'lng': -74.0003365},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '0.3 mi', 'value': 477},
#        'duration': {'text': '6 mins', 'value': 369},
#        'end_location': {'lat': 40.7388242, 'lng': -74.0080004},
#        'html_instructions': 'Continue onto <b>Horatio St</b>',
#        'polyline': {'points': 'wxswF~rtbM@hA?t@[h@h@j@?\\K??\\?~G?p@?`A@rAAd@?~G'},
#        'start_location': {'lat': 40.7388386, 'lng': -74.0025615},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '135 ft', 'value': 41},
#        'duration': {'text': '1 min', 'value': 30},
#        'end_location': {'lat': 40.7389303, 'lng': -74.0079928},
#        'html_instructions': 'Turn <b>right</b> onto <b>Washington St</b><div style="font-size:0.9em">Destination will be on the right</div>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'sxswF~tubME?OA'},
#        'start_location': {'lat': 40.7388242, 'lng': -74.0080004},
#        'travel_mode': 'WALKING'}],
#      'travel_mode': 'WALKING'}],
#    'traffic_speed_entry': [],
#    'via_waypoint': []}],
#  'overview_polyline': {'points': 'qhnxFlaraMJ@LFTr@RJZPZNGVzAt@]lBj@PFC@D@@?BBBFDH@NGBAHC|@^p@Xf@TVPRHVj@BFHFp@`@f@PTBd@B@IHTB??JAv@IbBMdAy@pDbBx@\\Lz@Lr@?~Ae@pAe@b@QXbBb@lCr@`D\\zA`@jAN\\FJJd@bArEjBlInCtLoBpEqDtIoCtGsEvKWn@CEOMVk@P|@IRc@dAMZjBfCz`Abw@fEfDz@v@t@t@p@v@fx@veAl@r@h@f@d@^xBtAhC~AlBr@jEzApAr@jBhBnL~O\\j@Nh@~@`JLhBA`AKz@S|@c@vAWx@Ef@?VFZPf@nBnBx@~@Zn@n@nBf@nBTnBF|BHhCRvB`@lBd@xAlGhMbA|A\\\\lAt@da@lS~At@`Bb@t@Jt@Dz\\F`@B^Nd@^Tb@hAlCx_@v~@bDnJb@pAn@rAvGfNVz@Hj@L`B@hCC`CO|Ec@fKFtA^bBRj@`@fBFh@@p@GnBkAzFkM`w@u@rEcAhGOdAWhCOdCGfCFvWDjAJfARdAZ~@^~@f@x@n@t@pwB|vArAdAd@z@Tn@Tz@ZbCrBdRzB|VFpAKpA_@tAqKv\\UjAKfA?dAJ~@Xz@b@x@p@t@ZXb[pSp^|UnGfF`ClBxQdM|CnBfAd@pAb@tG|AvHvAxBZxBTlCNxSVpC?`\\Wh@E~C_Aj@Gn@AdBLlGj@~B`@|C~@zB`AtAn@`B~@`HxDxAv@pBt@zBj@lEfAfA\\p@ZrAz@pj@p^hf@v[`f@j[e@Zy@hCsAbEMn@G|@@~B[h@h@j@?\\K??|H?lF?~GE?OA'},
#  'summary': '',
#  'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#  'waypoint_order': []}

# %%
def parse_transit_details(transit_resp):
    transit_details = {}
    legs = transit_resp['legs'][0]
    transit_steps = [x for x in legs['steps'] if x['travel_mode'] == 'TRANSIT']
    lines = [x['transit_details']['line']['short_name'] for x in transit_steps]
    transit_details['departure_time'] = parse_time(legs['departure_time']['value'])
    transit_details['arrival_time'] = parse_time(legs['arrival_time']['value'])
    transit_details['duration_hr'] = parse_duration(legs['duration']['value'])
    transit_details['duration_txt'] = legs['duration']['text']
    transit_details['distance_mi'] = parse_distance(legs['distance']['value'])
    transit_details['transit lines'] = lines
    transit_details['transit departure_time'] = [parse_time(x['transit_details']['departure_time']['value']) 
                                         for x in transit_steps]
    transit_details['transit arrival_time'] = [parse_time(x['transit_details']['arrival_time']['value']) 
                                         for x in transit_steps]
    transit_details['transit durations_hr'] = [parse_duration(x.get('duration').get('value')) 
                                            for x in transit_steps]
    transit_details = {k:str(v) if type(v) == list else v 
                      for k, v in transit_details.items()}
    return(pd.Series(transit_details))

# %%
transit_details1 = parse_transit_details(transit_resp)
transit_details1
# Out:
# departure_time                                          2021-09-03 15:22:35
# arrival_time                                            2021-09-03 16:49:52
# duration_hr                                                            1.45
# duration_txt                                                 1 hour 27 mins
# distance_mi                                                              16
# transit lines                                            ['Bx28', '5', '2']
# transit departure_time    ['2021-09-03 15:29:25', '2021-09-03 15:49:30',...
# transit arrival_time      ['2021-09-03 15:38:37', '2021-09-03 16:15:00',...
# transit durations_hr                                     [0.15, 0.42, 0.39]
# dtype: object

# %% [markdown]
# ## Demo Applying it

# %%
df.columns
# Out:
# Index(['origin', 'destination', 'mode', 'departure_time', 'Raw Response',
#        'Date', 'Time'],
#       dtype='object')

# %%
df['mode'].value_counts()
# Out:
# driving    139
# transit      9
# Name: mode, dtype: int64

# %%
transits = df[df['mode'] == 'transit'] 
transit_df = transits['Raw Response']\
    .apply(lambda x: parse_transit_details(literal_eval(x)[0]))
transit_df
# Out:
#          departure_time         arrival_time  duration_hr    duration_txt  \
# 1   2021-09-03 13:34:23  2021-09-03 15:09:25         1.58  1 hour 35 mins
# 3   2021-09-03 15:22:35  2021-09-03 16:49:52         1.45  1 hour 27 mins
# 5   2021-09-03 15:12:40  2021-09-03 16:46:48         1.57  1 hour 34 mins
# 7   2021-09-03 15:15:34  2021-09-03 16:41:52         1.44  1 hour 26 mins
# 9   2021-09-03 15:23:19  2021-09-03 16:49:52         1.44  1 hour 27 mins
# 11  2021-09-03 15:46:07  2021-09-03 17:11:48         1.43  1 hour 26 mins
# 13  2021-09-03 16:01:59  2021-09-03 17:33:55         1.53  1 hour 32 mins
# 15  2021-09-03 16:01:59  2021-09-03 17:33:55         1.53  1 hour 32 mins
# 17  2021-09-03 16:01:59  2021-09-03 17:33:55         1.53  1 hour 32 mins
#
#     distance_mi                 transit lines  \
# 1         18.31                 ['BxM7', 'E']
# 3         16.00            ['Bx28', '5', '2']
# 5         16.49       ['Bx12-SBS', '6X', 'L']
# 7         16.21                    ['5', '2']
# 9         16.00            ['Bx28', '5', '2']
# 11        16.49  ['Bx12-SBS', '6X', '5', 'L']
# 13        18.31                 ['BxM7', 'E']
# 15        18.31                 ['BxM7', 'E']
# 17        18.31                 ['BxM7', 'E']
#
#                                transit departure_time  \
# 1      ['2021-09-03 13:35:00', '2021-09-03 14:50:30']
# 3   ['2021-09-03 15:29:25', '2021-09-03 15:49:30',...
# 5   ['2021-09-03 15:16:08', '2021-09-03 15:40:00',...
# 7      ['2021-09-03 15:38:30', '2021-09-03 16:09:00']
# 9   ['2021-09-03 15:29:25', '2021-09-03 15:49:30',...
# 11  ['2021-09-03 15:52:08', '2021-09-03 16:12:00',...
# 13     ['2021-09-03 16:05:00', '2021-09-03 17:13:00']
# 15     ['2021-09-03 16:05:00', '2021-09-03 17:13:00']
# 17     ['2021-09-03 16:05:00', '2021-09-03 17:13:00']
#
#                                  transit arrival_time  \
# 1      ['2021-09-03 14:38:00', '2021-09-03 15:00:30']
# 3   ['2021-09-03 15:38:37', '2021-09-03 16:15:00',...
# 5   ['2021-09-03 15:23:00', '2021-09-03 16:30:00',...
# 7      ['2021-09-03 16:07:00', '2021-09-03 16:32:30']
# 9   ['2021-09-03 15:38:37', '2021-09-03 16:15:00',...
# 11  ['2021-09-03 15:59:00', '2021-09-03 16:37:30',...
# 13     ['2021-09-03 17:03:00', '2021-09-03 17:25:00']
# 15     ['2021-09-03 17:03:00', '2021-09-03 17:25:00']
# 17     ['2021-09-03 17:03:00', '2021-09-03 17:25:00']
#
#         transit durations_hr
# 1               [1.05, 0.17]
# 3         [0.15, 0.42, 0.39]
# 5         [0.11, 0.83, 0.04]
# 7               [0.48, 0.39]
# 9         [0.15, 0.42, 0.39]
# 11  [0.11, 0.42, 0.26, 0.04]
# 13               [0.97, 0.2]
# 15               [0.97, 0.2]
# 17               [0.97, 0.2]

# %%
driving = df[df['mode'] == 'driving'] 
driving_df = driving['Raw Response']\
    .apply(lambda x: parse_driving_details(literal_eval(x)[0]))
driving_df
# Out:
#                      summary  duration_hr duration_text  \
# 0         I-95 S and NY-9A S         0.78       47 mins
# 2                    NY-9A S         0.76       46 mins
# 4                    NY-9A S         0.76       46 mins
# 6                    NY-9A S         0.76       46 mins
# 8                    NY-9A S         0.76       46 mins
# ..                       ...          ...           ...
# 143  Hutchinson River Pkwy S         0.21       13 mins
# 144         Orchard Beach Rd         0.22       13 mins
# 145  Hutchinson River Pkwy S         0.21       13 mins
# 146         Orchard Beach Rd         0.22       13 mins
# 147  Hutchinson River Pkwy S         0.21       13 mins
#
#      duration_in_traffic_hr duration_in_traffic_text  time in traffic_min  \
# 0                      0.77                  46 mins                 -0.6
# 2                      0.83                  50 mins                  4.2
# 4                      0.84                  50 mins                  4.8
# 6                      0.84                  51 mins                  4.8
# 8                      0.87                  52 mins                  6.6
# ..                      ...                      ...                  ...
# 143                    0.21                  13 mins                  0.0
# 144                    0.22                  13 mins                  0.0
# 145                    0.20                  12 mins                 -0.6
# 146                    0.22                  13 mins                  0.0
# 147                    0.20                  12 mins                 -0.6
#
#      distance_mi                            1st Longest Step (time)  \
# 0          18.57  {'Step #': 10, 'distance_mi': 8.58, 'duration_...
# 2          24.13  {'Step #': 15, 'distance_mi': 8.15, 'duration_...
# 4          24.13  {'Step #': 15, 'distance_mi': 8.15, 'duration_...
# 6          24.12  {'Step #': 15, 'distance_mi': 8.15, 'duration_...
# 8          24.13  {'Step #': 15, 'distance_mi': 8.15, 'duration_...
# ..           ...                                                ...
# 143         3.83  {'Step #': 10, 'distance_mi': 0.36, 'duration_...
# 144         3.83  {'Step #': 5, 'distance_mi': 0.54, 'duration_h...
# 145         3.83  {'Step #': 10, 'distance_mi': 0.36, 'duration_...
# 146         3.83  {'Step #': 5, 'distance_mi': 0.54, 'duration_h...
# 147         3.83  {'Step #': 10, 'distance_mi': 0.36, 'duration_...
#
#                                2nd Longest Step (time)  \
# 0    {'Step #': 8, 'distance_mi': 5.37, 'duration_h...
# 2    {'Step #': 14, 'distance_mi': 4.66, 'duration_...
# 4    {'Step #': 14, 'distance_mi': 4.66, 'duration_...
# 6    {'Step #': 14, 'distance_mi': 4.66, 'duration_...
# 8    {'Step #': 14, 'distance_mi': 4.66, 'duration_...
# ..                                                 ...
# 143  {'Step #': 12, 'distance_mi': 0.29, 'duration_...
# 144  {'Step #': 3, 'distance_mi': 0.31, 'duration_h...
# 145  {'Step #': 12, 'distance_mi': 0.29, 'duration_...
# 146  {'Step #': 3, 'distance_mi': 0.31, 'duration_h...
# 147  {'Step #': 12, 'distance_mi': 0.29, 'duration_...
#
#                                3rd Longest Step (time)
# 0    {'Step #': 4, 'distance_mi': 0.38, 'duration_h...
# 2    {'Step #': 9, 'distance_mi': 2.0, 'duration_hr...
# 4    {'Step #': 9, 'distance_mi': 2.0, 'duration_hr...
# 6    {'Step #': 6, 'distance_mi': 0.78, 'duration_h...
# 8    {'Step #': 9, 'distance_mi': 2.0, 'duration_hr...
# ..                                                 ...
# 143  {'Step #': 8, 'distance_mi': 0.94, 'duration_h...
# 144  {'Step #': 13, 'distance_mi': 0.27, 'duration_...
# 145  {'Step #': 8, 'distance_mi': 0.94, 'duration_h...
# 146  {'Step #': 13, 'distance_mi': 0.27, 'duration_...
# 147  {'Step #': 8, 'distance_mi': 0.94, 'duration_h...
#
# [139 rows x 10 columns]

# %%
driving_full = pd.merge(driving, driving_df
         , left_index=True, right_index=True)
transit_full = pd.merge(transits, transit_df
                       , left_index=True, right_index=True)
